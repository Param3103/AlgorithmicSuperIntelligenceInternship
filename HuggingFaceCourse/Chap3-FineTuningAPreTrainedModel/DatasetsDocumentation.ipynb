# %%
# Load dataset
from datasets import load_dataset, Audio

dataset = load_dataset("PolyAI/minds14", "en-US", split="train")
dataset
# Out:
# Dataset({
#     features: ['path', 'audio', 'transcription', 'english_transcription', 'intent_class', 'lang_id'],
#     num_rows: 563
# })

# %%
from transformers import AutoModelForAudioClassification, AutoFeatureExtractor

model = AutoModelForAudioClassification.from_pretrained("facebook/wav2vec2-base")
feature_extractor = AutoFeatureExtractor.from_pretrained("facebook/wav2vec2-base")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 3
#       1 from transformers import AutoModelForAudioClassification, AutoFeatureExtractor
# ----> 3 model = AutoModelForAudioClassification.from_pretrained("facebook/wav2vec2-base")
#       4 feature_extractor = AutoFeatureExtractor.from_pretrained("facebook/wav2vec2-base")
#
# File c:\Users\param\CodingWorkspace\AlgorithmicSuperIntelligenceInternship\Lib\site-packages\transformers\utils\import_utils.py:1997, in DummyObject.__getattribute__(cls, key)
#    1995 if (key.startswith("_") and key != "_from_config") or key == "is_dummy" or key == "mro" or key == "call":
#    1996     return super().__getattribute__(key)
# -> 1997 requires_backends(cls, cls._backends)
#
# File c:\Users\param\CodingWorkspace\AlgorithmicSuperIntelligenceInternship\Lib\site-packages\transformers\utils\import_utils.py:1983, in requires_backends(obj, backends)
#    1980         failed.append(msg.format(name))
#    1982 if failed:
# -> 1983     raise ImportError("".join(failed))
#
# ImportError:
# AutoModelForAudioClassification requires the PyTorch library but it was not found in your environment. Check out the instructions on the
# installation page: https://pytorch.org/get-started/locally/ and follow the ones that match your environment.
# Please note that you may need to restart your runtime after installation.
